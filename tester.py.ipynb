# %%
"""
Compiles a list of all the clubs that the Finance Committee can fund,
given some raw input files.
"""

# temporary debugging variable
output = None

def main():
    global output
    
    # read the osl clubs and club sports files

    # file paths
    # TODO make this configurable
    osl_clubs_path = "osl-clubs-raw.txt"
    club_sports_path = "club-sports-raw.txt"
    output_path = "ficom-clubs.txt"

    # open files
    with open(osl_clubs_path,"r") as osl_clubs_file, open(club_sports_path,"r") as club_sports_file:        
        # read these into lists
        osl_clubs = osl_clubs_file.read().splitlines()
        club_sports = club_sports_file.read().splitlines()

        # clean each list by removing duplicates, trimming spaces, etc
        osl_clubs_cleaned = clean_list(osl_clubs)
        club_sports_cleaned = clean_list(club_sports)
    
        # ok now merge these 
        merged = []
        merged.extend(osl_clubs_cleaned)
        merged.extend(club_sports_cleaned)
        
        # now that we have the full list, we have some UC-specific things to remove
        # first, remove anything with PBHA 
        no_pbha = [s for s in merged if s.find("PBHA") < 0]
        
        # now remove the UC itself 
        no_uc = [s for s in no_pbha if s.find("Undergraduate Council") < 0]
        
        # sort it before reporting
        # sort case insensitively
        sorted_list = sorted(no_uc, key=lambda s: s.lower())

        # report answer 
        output = sorted_list 
        
        # write the list to a file, with one club per line
        with open(output_path, "w") as outfile:
            for line in output:
                # this just means to write the line of text with a newline ("\n") at the end
                outfile.write("{}\n".format(line))
        
        pri

def clean_list(raw_list):
    """
    Cleans up a list of raw text by:
        -   Removing blank lines 
        -   Trimming extra spaces 
        -   Removing duplicates 
    """
    # first strip extra spaces 
    stripped = [s.strip() for s in raw_list]
    
    # remove blank lines 
    no_empties = [s for s in stripped if s != ""]
    
    # remove duplicates just to be safe
    no_duplicates = list(set(no_empties))
    
    return no_duplicates


if __name__ == "__main__":
    main()

# %%
out
# Out:
# ['Access Health',
#  'Act On A Dream',
#  'Advocating Success for Kids',
#  'Africa Business and Investment Club (HABIC)',
#  'African Students Association (HASA)',
#  'Aikikai',
#  "Alzheimer's Buddies",
#  'Anime Society',
#  'Anscombe Society',
#  'Applied Mathematics Society',
#  'Archery',
#  'Armenian Students Association',
#  'Asian American Association (AAA)',
#  'Asian American Brotherhood (AAB)',
#  'Asian American Christian Fellowship (AACF)',
#  'Asian American Dance Troupe (AADT)',
#  "Asian American Women's Association",
#  'Asian Baptist Student Koinonia (ABSK)',
#  'Aspiring Minority Business Leaders and Entrepreneurs (AMBLE)',
#  'Association for the Promotion of Interplanetary Expansion (HAPIE)',
#  'Association for U.S.-China Relations (HAUSCR)',
#  'Association of Black Harvard Women (ABHW)',
#  'Association of Practice and Learning of Yan Xin Life Science & Technology',
#  'Astrophysical Society',
#  'Athena Conference',
#  'Australian Undergraduate Society (AUS)',
#  'Bach Society Orchestra (BachSoc)',
#  'Badminton',
#  "Baha'i Association",
#  'Ballet Company',
#  'Ballroom Dance',
#  'Ballroom Dance Team (HBDT)',
#  'Baroque Chamber Orchestra',
#  'Baseball',
#  'Beekeepers',
#  'Bhangra',
#  'Billiards',
#  'Bioethics Society',
#  'Biomedical Engineering Society (BMES)',
#  'Biotechnology Association',
#  "Black Men's Forum (BMF)",
#  'Black Pre-Law Association (BPLA)',
#  'Black Students Association (BSA)',
#  'BlackC.A.S.T.',
#  'Bowling',
#  'Boxing',
#  'Brattle Street Chamber Players',
#  'Brazilian Association (HUBA)',
#  'Breakers',
#  'British Club',
#  'Broomball',
#  'Bulgarian Club',
#  'BWISE: BSC Fellows for a Whole Integrated Student Experience',
#  'Canadian Club',
#  'Cancer Society',
#  'Candela Dance Troupe',
#  'Capoeira',
#  'Caribbean Club',
#  'Catholic Student Association (CSA)',
#  'CEB',
#  'Chado Society',
#  'Cheerleading',
#  'Chemistry Club',
#  'Chess Club',
#  "Children's Stories",
#  'China Forum (HCCF)',
#  'Chinese International Students Society (CISS)',
#  'Chinese Music Ensemble (HCME)',
#  'Chinese Students Association (CSA)',
#  'Christian Impact',
#  'Christians on Campus',
#  'Circle of Women',
#  'CityStep',
#  'Classics Club',
#  'Climbing',
#  'Coalition for East African Peace',
#  'College Bowl',
#  'Collegium',
#  'Colombian Students Association',
#  'Community Garden',
#  'Community of Humanists, Atheists, and Agnostics',
#  'Composers Association',
#  'Computer Society (HCS)',
#  'Concilio Latino',
#  'Consent Advocates and Relationship Educators (CARE)',
#  'Conservation Society',
#  'Consulting Group (HCCG)',
#  'Consulting on Business and the Environment',
#  'Contact Peer Counseling',
#  'Cornhole',
#  'Cricket',
#  'Crimson',
#  'Crimson Dance',
#  'Crimson Key Society (CKS)',
#  'CrimsonEMS',
#  'Cuban-American Undergraduate Student Association (CAUSA)',
#  'Cube Club',
#  'Curling',
#  'Cycling',
#  'Dancing to Heal',
#  'Debate Council',
#  'Debating Union',
#  'Deepam',
#  'Democrats',
#  'Developers for Development',
#  'Development Think Tank',
#  'Dharma',
#  'Digital Literacy Project',
#  'Din & Tonics',
#  'Disability Alliance',
#  'DPE',
#  'DREAM',
#  'Dreamporte',
#  'Drug and Alcohol Peer Advisors (DAPA)',
#  'Early Music Society (HEMS)',
#  'Eating Concerns Hotline and Outreach (ECHO)',
#  'Ecdysis',
#  'Ecomarathon Team',
#  'Economics Association',
#  'Economics Review',
#  'Effective Altruism',
#  'Egyptian Student Association',
#  'Electronic Music Collective',
#  'Eleganza',
#  'Engineering Society (HCES)',
#  'Engineers Without Borders (EWB)',
#  'Entertainment Society',
#  'Entrepreneurship Forum',
#  'Episcopal Students',
#  'Esports Association',
#  'European Business Group',
#  'European Society',
#  'Evening with Champions',
#  'Expressions',
#  'Faith and Action (HCFA)',
#  'Fed Challenge',
#  'Fencing',
#  'Field Hockey',
#  'Figure Skating',
#  'Film Festival',
#  'Financial Analysts Club',
#  'First Generation Student Union',
#  'First-Year Outdoor Program (FOP)',
#  'First-Year Social Committee (FYSC)',
#  'Flag Football',
#  'Flute Ensemble',
#  'Food Lab for Kids',
#  'Food Literacy Project',
#  'Foundation for International Medical Relief of Children (FIMRC)',
#  'Francophone Society',
#  'Franklin Fellowship',
#  'Friends of Chabad',
#  'Friends of Project Sunshine',
#  'Friends of Scouting',
#  'Fuerza Latina',
#  'FUSIAN',
#  'Futsal',
#  'Future Surgeons',
#  'Gaongil: Modern Korean Studies Society',
#  'Gap Year',
#  'Gender Inclusivity in Math',
#  'Geological Society',
#  'Gilbert & Sullivan Players (HRG&SP)',
#  'Glee Club',
#  'Global Health and AIDS Coalition',
#  'Global Health Forum (HUGHF)',
#  'Golf',
#  'Green Medicine Initiative',
#  'HackHarvardCollege',
#  "Half Asian People's Association (HAPA)",
#  'Hapkido',
#  'Harvard Association Cultivating Inter-American Democracy (HACIA Democracy)',
#  'Harvard College Coaches',
#  'Harvard College in Asia Program (HCAP)',
#  'Harvard Organization for Latin America (HOLA)',
#  'Harvard Student Agencies (HSA)',
#  'Harvard Undergraduates Raising Autism Awareness! (HURAA!)',
#  'Harvard University Band',
#  'Harvard-Radcliffe Orchestra (HRO)',
#  'Hasty Pudding Theatricals (HPT)',
#  'HBASIS (Harvard College Bisexual, Gay, Lesbian, Transgender, Queer & Allied Students in the Sciences)',
#  'Healing Thoughts',
#  'Health Advocacy Program (HAP)',
#  'Health Leads',
#  'Health Policy Review',
#  'Healthcare Associates',
#  'HealthPALs - Health Peer Advisors & Liaisons',
#  'Hellenic Society',
#  'High School CityServe',
#  'Hillel',
#  'Holoimua O Hawaii',
#  'Hong Kong Society',
#  'Honor Council',
#  'HRDC (Harvard--Radcliffe Dramatic Club)',
#  'HUBBS',
#  'Human Rights in North Korea (HRiNK)',
#  'Human Rights Review',
#  'Hyperion Shakespeare Company',
#  'IDENTITIES Fashion Show',
#  'iGEM',
#  'Immediate Gratification Players (IGP)',
#  'Impact Investing Group',
#  'Indigo Peer Counseling',
#  'Inside Voices Step Team',
#  'Institute of Politics (IOP)',
#  'Intercollegiate Model United Nations',
#  'Interfaith Forum',
#  'International Negotiation Program',
#  'International Relations Council (IRC)',
#  'International Relations on Campus',
#  'International Review',
#  "International Women's Rights Collective (IWRC)",
#  'Investment Association (HIA)',
#  'Iranian Association',
#  'Islamic Society (HIS)',
#  'Israel Public Affairs',
#  'Italian Society',
#  'Ivory Tower',
#  'Ivy Council',
#  'Japan Society',
#  'Jazz Bands',
#  'Jiu Jitsu',
#  'John Adams Society',
#  'Kendo',
#  'KeyChange',
#  'Kidney Disease Screening and Awareness Program (KDSAP)',
#  'Korean Adoptee Mentorship Program',
#  'Korean Association (KA)',
#  'Korean International Student Association (KISA)',
#  'Krav Maga',
#  'Kuumba Singers',
#  'La Organizacion de Puertorriquenos en Harvard',
#  'Lampoon',
#  'Latinas Unidas',
#  "Latino Men's Collective (LMC)",
#  'Latinos in Health Careers',
#  'Latter-day Saint Student Association (LDSSA)',
#  'Law Society',
#  'Leadership Institute at Harvard College (LIHC)',
#  'Libertarian Club',
#  'Lowell House Opera Society',
#  'Lowell House Society of Russian Bell Ringers',
#  'LowKeys',
#  "Magicians' Society",
#  'Manifesta Magazine',
#  'Mariachi Veritas',
#  'Mathematics Association (HUMA)',
#  'Medical Humanities Forum',
#  'Meditation Club',
#  "Men's Basketball (Crimson Classics)",
#  "Men's Basketball (Harvard Hoopsters)",
#  "Men's Ice Hockey",
#  "Men's Lacrosse",
#  "Men's Rugby",
#  "Men's Soccer",
#  "Men's Tennis",
#  'Mentors for Urban Debate',
#  'Mirch',
#  'Mock Trial',
#  'Model Congress (HMC)',
#  'Model Congress Asia',
#  'Model Congress Europe (HMCE)',
#  'Model Congress Latin America (MCLA)',
#  'Model Congress Middle East',
#  'Model Congress San Francisco',
#  'Model Security Council (MSC)',
#  'Model United Nations (HMUN)',
#  'Modern Dance Company (HRMDC)',
#  'Mountaineering Club',
#  'Mozart Society Orchestra (MSO)',
#  'Music in Hospitals and Nursing Homes Using Entertainment as Therapy (MIHNUET)',
#  'Musical Theater',
#  'National Model United Nations (HNMUN)',
#  'Native Americans at Harvard College (NAHC)',
#  'Naturalist Club',
#  'Network of Enlightened Women',
#  'Nigerian Students Association (NSA)',
#  'Nordic Skiing',
#  "Noteables-Harvard's Broadway Beat",
#  'On Harvard Time (OHT)',
#  'On Thin Ice (OTI)',
#  'Open Campus Initiative',
#  'Open Philosophy Organization',
#  'Opera Society',
#  'Opportunes',
#  'Organ Society',
#  'Organization of Asian American Sisters in Service',
#  'Orthodox Christian Fellowship',
#  'Outing Club',
#  'Pakistan Student Association',
#  'Palestine Solidarity Committee (PSC)',
#  'Pan-African Dance and Music Ensemble (PADAME)',
#  'Partners in Health Engage',
#  'Passus: Harvard College Step Team',
#  'Pediatric Pals',
#  'Philippine Forum',
#  'Photography Club',
#  'Piano Society',
#  'Pistol',
#  'Polish Society',
#  'Political Review (HPR)',
#  'Polo',
#  'Pop Culture Club',
#  'Pops Orchestra',
#  'Powerlifting',
#  'Pre-Medical Society',
#  'Pre-Veterinary Society',
#  'Presencia Latina',
#  'Program for International Education (HPIE)',
#  'Progressive Jewish Alliance (PJA)',
#  'Project for Asian and International Relations (HPAIR)',
#  'Project for Justice',
#  'Project SWIM',
#  'Quad Sound Studios (QSS)',
#  'Quantitative Trading Club',
#  'Queer Students and Allies (QSA)',
#  'Quidditch',
#  'Radcliffe Choral Society (RCS)',
#  'Radcliffe Pitches',
#  'Radcliffe Union of Students (RUS)',
#  'Raftaar',
#  'RAZA',
#  'Recreational Experience and Arts Creativity with Harvard (REACH)',
#  'Red Cross',
#  'Republican Club',
#  'Reserve Officer Training Corps Association (HROTCA)',
#  'Response',
#  'Review of Environment and Society',
#  'Rhythmic Gymnastics',
#  'Right to Life',
#  'River Charles Ensemble',
#  'Robotics Club',
#  'Romanian Association',
#  'Room 13',
#  'Rootstrikers',
#  'Running',
#  'Rural Health Association',
#  'Russian Speakers Association',
#  'Satire V',
#  'Scholars at Risk',
#  'School of Rock',
#  'Science Club for Girls',
#  'Science Fiction Association (HRSFA)',
#  'Science Review',
#  'Scientista',
#  'Scuba',
#  'Senior Class Committee',
#  'Seventh-day Adventist Fellowship (HCSDAF)',
#  'Sexual Health and Relationship Counselors (SHARC)',
#  'Sexual Health Education & Advocacy throughout Harvard College (SHEATH)',
#  'SHADE',
#  'Shooting',
#  'Shotokan Karate',
#  'Sikh Student Association',
#  'Simplicissimus',
#  'Singaporean, Indonesia, and Malaysia Association (SIAMA)',
#  'Skiing',
#  'Slav Squad',
#  'Smart Woman Securities (SWS)',
#  'Social Enterprise Association (HCSEA)',
#  'Social Innovation Collaborative',
#  'Society for Mind, Brain, and Behavior (HSMBB)',
#  'Society for the Cinematic Arts',
#  'Society of Arab Students',
#  'Society of Black Scientists and Engineers (HSBSE)',
#  'Society of Physics Students (SPS)',
#  'Softball',
#  'SoulFood Christian Fellowship',
#  'South Asian Association (SAA)',
#  "South Asian Men's Collective (SAMC)",
#  "South Asian Women's Collective",
#  'South Slavic Society',
#  'Speak Out Loud (SOL)',
#  'Special Olympics',
#  'Spikeball',
#  'Sports Analysis Collective',
#  'Springboard Design',
#  'Squash',
#  'Stand-Up Comic Society (HCSUCS)',
#  'Stem Cell Society',
#  'Story-Time Players',
#  'STRIVE',
#  'Student Astronomers at Harvard-Radcliffe (STAHR)',
#  'Student for Myanmar',
#  'Student Mental Health Liaisons (SMHL)',
#  'Student Theater Advancing Growth & Empowerment (S.T.A.G.E.)',
#  'Students for Israel',
#  'Students for the Exploration and Development of Space (SEDS)',
#  'Swimming',
#  'Swiss Club',
#  'Table Tennis',
#  'Taekwondo',
#  'Taiwan Leadership Conference',
#  'Taiwanese Cultural Society (TCS)',
#  'TAMID',
#  'TAPS',
#  'Task Force on Asian and Pacific American Studies',
#  'Team Handball',
#  'Team HBV',
#  'TEDx Harvard College',
#  'Tempus',
#  'Texas Club',
#  'Thai Society',
#  'The Advocate',
#  'The Harvard Callbacks',
#  'The Harvard Krokodiloes, Inc.',
#  'The Harvard Undergraduate Research Journal (THURJ)',
#  'The Ichthus',
#  'The Independent',
#  'The Review of Philosophy',
#  'The Salient',
#  'Three Letter Acronym: Harold Team (TLA)',
#  'THUD (The Harvard Undergraduate Drummers)',
#  'Tough Mudder',
#  'Triathlon',
#  'Tuesday Magazine',
#  'Turkish Student Association',
#  'Ultimate Frisbee (Men)',
#  'Ultimate Frisbee (Women)',
#  'Under Construction',
#  'Undergraduate Alumni Connection (HUAC)',
#  'Undergraduate Fellowship (HUF)',
#  'Undergraduate Research Association (HCURA)',
#  'United World Club',
#  'University Choir',
#  'US-India Initiative',
#  'Vegetarian Society (Vegitas)',
#  'Ventures (Harvard College)',
#  'Veritas Financial Group (VFG)',
#  'Veritones',
#  'Veritutor Writing Helpline',
#  'Video Game Development Club',
#  'Vietnamese Association',
#  'VISION',
#  'Volleyball (Men)',
#  'Volleyball (Women)',
#  'Wall Handball',
#  'Water Polo',
#  'WHRB (Harvard Radio Broadcasting)',
#  'Wind Ensemble',
#  'Wine Society',
#  'Wireless Club',
#  'Wisconsin Club (H-COW)',
#  'Women in Business (HUWIB)',
#  'Women in Computer Science',
#  'Women In Science at Harvard-Radcliffe (WISHR)',
#  "Women's Basketball",
#  "Women's Ice Hockey",
#  "Women's Lacrosse",
#  "Women's Leadership Project (WLP)",
#  "Women's Soccer",
#  "Women's Tennis",
#  'Woodbridge International Society',
#  'World Model United Nations (WorldMUN)',
#  "Writers' Workshop",
#  'Writing and Public Service Initiative',
#  'Wushu',
#  'XFit',
#  'Yearbook',
#  'YouthGlobe']

# %%
st = [s.strip() for s in osl_clubs]

# %%
st
# Out:
# ['',
#  '1-2-1 Boston Refugee Youth Enrichment (PBHA)',
#  'Access Health',
#  'Act On A Dream',
#  'Advocating Success for Kids',
#  'Africa Business and Investment Club (HABIC)',
#  'African Students Association (HASA)',
#  'Alternative Spring Breaks (ASB) (PBHA)',
#  "Alzheimer's Buddies",
#  'Anime Society',
#  'Anscombe Society',
#  'Applied Mathematics Society',
#  'Armenian Students Association',
#  'Asian American Association (AAA)',
#  'Asian American Brotherhood (AAB)',
#  'Asian American Christian Fellowship (AACF)',
#  'Asian American Dance Troupe (AADT)',
#  "Asian American Women's Association",
#  'Asian Baptist Student Koinonia (ABSK)',
#  'Aspiring Minority Business Leaders and Entrepreneurs (AMBLE)',
#  'Association for the Promotion of Interplanetary Expansion (HAPIE)',
#  'Association for U.S.-China Relations (HAUSCR)',
#  'Association of Black Harvard Women (ABHW)',
#  'Association of Practice and Learning of Yan Xin Life Science & Technology',
#  'Astrophysical Society',
#  'Athena Conference',
#  'Australian Undergraduate Society (AUS)',
#  'Bach Society Orchestra (BachSoc)',
#  "Baha'i Association",
#  'Ballet Company',
#  'Ballroom Dance Team (HBDT)',
#  'Baroque Chamber Orchestra',
#  'Beekeepers',
#  'Best Buddies (PBHA)',
#  'Bhangra',
#  'Bioethics Society',
#  'Biomedical Engineering Society (BMES)',
#  'Biotechnology Association',
#  "Black Men's Forum (BMF)",
#  'Black Pre-Law Association (BPLA)',
#  'Black Students Association (BSA)',
#  'BlackC.A.S.T.',
#  'Boston Refugee Youth Enrichment (BRYE Term) (PBHA)',
#  'Boston Refugee Youth Enrichment (BRYE) Extension (PBHA)',
#  'Boston Refugee Youth Enrichment (BRYE) Tutoring (PBHA)',
#  'Boston Refugee Youth Enrichment Summer Program (BRYE Summer) (PBHA)',
#  'Brattle Street Chamber Players',
#  'Brazilian Association (HUBA)',
#  'Breakers',
#  'British Club',
#  'BRYE Teen (PBHA)',
#  'Bulgarian Club',
#  'BWISE: BSC Fellows for a Whole Integrated Student Experience',
#  'Cambridge 1-2-1 (PBHA)',
#  'Cambridge Afterschool Program (CASP) (PBHA)',
#  'Cambridge Youth Enrichment Program (CYEP) (PBHA)',
#  'Canadian Club',
#  'Cancer Society',
#  'Candela Dance Troupe',
#  'Caribbean Club',
#  'Catholic Student Association (CSA)',
#  'CEB',
#  'Chado Society',
#  'CHANCE (PBHA)',
#  'Chemistry Club',
#  'Chess Club',
#  "Children's Stories",
#  'China Forum (HCCF)',
#  'Chinatown Adventure (CHAD) (PBHA)',
#  'Chinatown Afterschool Program (CHTNASP) (PBHA)',
#  'Chinatown Big Sibling Program (PBHA)',
#  'Chinatown Citizenship Program (PBHA)',
#  'Chinatown ESL Program (PBHA)',
#  'Chinatown Teen Program (PBHA)',
#  'Chinese International Students Society (CISS)',
#  'Chinese Music Ensemble (HCME)',
#  'Chinese Students Association (CSA)',
#  'Christian Impact',
#  'Christians on Campus',
#  'Circle of Women',
#  'CityStep',
#  'CIVICS (PBHA)',
#  'Classics Club',
#  'Coalition for East African Peace',
#  'College Bowl',
#  'Collegium',
#  'Colombian Students Association',
#  'Community Garden',
#  'Community of Humanists, Atheists, and Agnostics',
#  'Composers Association',
#  'Computer Society (HCS)',
#  'Concilio Latino',
#  'Connelly Center Youth Prison Tutoring Program (PBHA)',
#  'Consent Advocates and Relationship Educators (CARE)',
#  'Conservation Society',
#  'Consulting Group (HCCG)',
#  'Consulting on Business and the Environment',
#  'Contact Peer Counseling',
#  'Crimson Key Society (CKS)',
#  'CrimsonEMS',
#  'Crimson',
#  'Cuban-American Undergraduate Student Association (CAUSA)',
#  'Cube Club',
#  'Dancing to Heal',
#  'David Walker Scholars (DWS) (PBHA)',
#  'Deaf Awareness Club (DAC) (PBHA)',
#  'Debate Council',
#  'Debating Union',
#  'Deepam',
#  'Democrats',
#  'Developers for Development',
#  'Development Think Tank',
#  'Dharma',
#  'Digital Literacy Project',
#  'Din & Tonics',
#  'Disability Alliance',
#  'DPE',
#  'DREAM',
#  'Dreamporte',
#  'Drug and Alcohol Peer Advisors (DAPA)',
#  'Early Music Society (HEMS)',
#  'Eating Concerns Hotline and Outreach (ECHO)',
#  'Ecdysis',
#  'Ecomarathon Team',
#  'Economics Association',
#  'Economics Review',
#  'Effective Altruism',
#  'Egyptian Student Association',
#  'Elderly 1-2-1 (PBHA)',
#  'Electronic Music Collective',
#  'Eleganza',
#  'Engineering Society (HCES)',
#  'Engineers Without Borders (EWB)',
#  'Entertainment Society',
#  'Entrepreneurship Forum',
#  'EnviroEd (PBHA)',
#  'Environmental Action Committee (EAC) (PBHA)',
#  'Episcopal Students',
#  'Esports Association',
#  'European Business Group',
#  'European Society',
#  'Evening with Champions',
#  'Experimentors (PBHA)',
#  'Expressions',
#  'Faith and Action (HCFA)',
#  'Fed Challenge',
#  'Film Festival',
#  'Financial Analysts Club',
#  'First Generation Student Union',
#  'First-Year Outdoor Program (FOP)',
#  'First-Year Social Committee (FYSC)',
#  'Flute Ensemble',
#  'Food Lab for Kids',
#  'Food Literacy Project',
#  'Foundation for International Medical Relief of Children (FIMRC)',
#  'Francophone Society',
#  'Franklin Afterschool Enrichment (FASE) (PBHA)',
#  'Franklin Fellowship',
#  'Franklin I-O Summer Program (FIO) (PBHA)',
#  'Franklin Teen Mentoring Program (PBHA)',
#  'Friends of Chabad',
#  'Friends of Project Sunshine',
#  'Friends of Scouting',
#  'Fuerza Latina',
#  'FUSIAN',
#  'Future Surgeons',
#  'Gaongil: Modern Korean Studies Society',
#  'Gap Year',
#  'Gender Inclusivity in Math',
#  'Geological Society',
#  'Gilbert & Sullivan Players (HRG&SP)',
#  'Glee Club',
#  'Global Health and AIDS Coalition',
#  'Global Health Forum (HUGHF)',
#  'Green Medicine Initiative',
#  'Habitat for Humanity (PBHA)',
#  'HackHarvardCollege',
#  "Half Asian People's Association (HAPA)",
#  'HARMONY Mentoring (PBHA)',
#  "Harvard Artists for Alzheimer's (PBHA)",
#  'Harvard Association Cultivating Inter-American Democracy (HACIA Democracy)',
#  'Harvard College Coaches',
#  'Harvard College in Asia Program (HCAP)',
#  'Harvard College Youth Leadership Initiative (HYLI) (PBHA)',
#  'Harvard Emerging Literacy Program (HELP) (PBHA)',
#  'Harvard Organization for Latin America (HOLA)',
#  'Harvard Square Homeless Shelter (HSHS) (PBHA)',
#  'Harvard Square Homeless Shelter Summer (HSHS) (PBHA)',
#  'Harvard Student Agencies (HSA)',
#  'Harvard Undergraduates Raising Autism Awareness! (HURAA!)',
#  'Harvard University Band',
#  'Harvard-Radcliffe Orchestra (HRO)',
#  'Hasty Pudding Theatricals (HPT)',
#  'HBASIS (Harvard College Bisexual, Gay, Lesbian, Transgender, Queer & Allied Students in the Sciences)',
#  'Healing Thoughts',
#  'Health Advocacy Program (HAP)',
#  'Health Leads',
#  'Health Policy Review',
#  'Healthcare Associates',
#  'HealthPALs - Health Peer Advisors & Liaisons',
#  'Hellenic Society',
#  'High School CityServe',
#  'Hillel',
#  'Holoimua O Hawaii',
#  'Hong Kong Society',
#  'Honor Council',
#  'HRDC (Harvard--Radcliffe Dramatic Club)',
#  'HUBBS',
#  'Human Rights in North Korea (HRiNK)',
#  'Human Rights Review',
#  'Hyperion Shakespeare Company',
#  'IDENTITIES Fashion Show',
#  'iGEM',
#  'Immediate Gratification Players (IGP)',
#  'Impact Investing Group',
#  'Indigo Peer Counseling',
#  'Inside Voices Step Team',
#  'Institute of Politics (IOP)',
#  'Intercollegiate Model United Nations',
#  'Interfaith Forum',
#  'International Negotiation Program',
#  'International Relations Council (IRC)',
#  'International Relations on Campus',
#  'International Review',
#  "International Women's Rights Collective (IWRC)",
#  'Investment Association (HIA)',
#  'Iranian Association',
#  'Islamic Society (HIS)',
#  'Israel Public Affairs',
#  'Italian Society',
#  'Ivory Tower',
#  'Ivy Council',
#  'Japan Society',
#  'Jazz Bands',
#  'John Adams Society',
#  'KeyChange',
#  'Keylatch Afterschool Program (KASP) (PBHA)',
#  'Keylatch Mentor Program (PBHA)',
#  'Keylatch Summer Program (KSP) (PBHA)',
#  'Kidney Disease Screening and Awareness Program (KDSAP)',
#  'Kids with Special Needs Achievement Program (KSNAP) (PBHA)',
#  'Korean Adoptee Mentorship Program',
#  'Korean Association (KA)',
#  'Korean International Student Association (KISA)',
#  'Kuumba Singers',
#  'La Organizacion de Puertorriquenos en Harvard',
#  'Lampoon',
#  'Latinas Unidas',
#  "Latino Men's Collective (LMC)",
#  'Latinos in Health Careers',
#  'Latter-day Saint Student Association (LDSSA)',
#  'Law Society',
#  "LEADER'S! (PBHA)",
#  'LEADERS! Program (PBHA)',
#  'Leadership Institute at Harvard College (LIHC)',
#  'Libertarian Club',
#  'Lowell House Opera Society',
#  'Lowell House Society of Russian Bell Ringers',
#  'LowKeys',
#  "Magicians' Society",
#  'Manifesta Magazine',
#  'Mariachi Veritas',
#  'Mathematics Association (HUMA)',
#  'Medical Humanities Forum',
#  'Meditation Club',
#  'Mentors for Urban Debate',
#  'Mirch',
#  'Mission Hill Afterschool Program (MHASP) (PBHA)',
#  'Mission Hill Summer Program (MHSP) (PBHA)',
#  'Mission Mentor (PBHA)',
#  'Mock Trial',
#  'Model Congress (HMC)',
#  'Model Congress Asia',
#  'Model Congress Europe (HMCE)',
#  'Model Congress Latin America (MCLA)',
#  'Model Congress Middle East',
#  'Model Congress San Francisco',
#  'Model Security Council (MSC)',
#  'Model United Nations (HMUN)',
#  'Modern Dance Company (HRMDC)',
#  'Mountaineering Club',
#  'Mozart Society Orchestra (MSO)',
#  'Music in Hospitals and Nursing Homes Using Entertainment as Therapy (MIHNUET)',
#  'Musical Theater',
#  'National Model United Nations (HNMUN)',
#  'Native American Youth Education Mentor Program (NAYEP Mentor) (PBHA)',
#  'Native American Youth Enrichment Program (NAYEP) (PBHA)',
#  'Native Americans at Harvard College (NAHC)',
#  'Naturalist Club',
#  'Network of Enlightened Women',
#  'Nigerian Students Association (NSA)',
#  "Noteables-Harvard's Broadway Beat",
#  'On Harvard Time (OHT)',
#  'On Thin Ice (OTI)',
#  'Open Campus Initiative',
#  'Open Philosophy Organization',
#  'Opera Society',
#  'Opportunes',
#  'Organ Society',
#  'Organization of Asian American Sisters in Service',
#  'Orthodox Christian Fellowship',
#  'Outing Club',
#  'Pakistan Student Association',
#  'Palestine Solidarity Committee (PSC)',
#  'Pan-African Dance and Music Ensemble (PADAME)',
#  'Partners Empowering Neighborhoods (PEN) (PBHA)',
#  'Partners in Health Engage',
#  'Passus: Harvard College Step Team',
#  "PBHA'S Summer CIVICS",
#  "PBHA's Summer HARMONY",
#  "PBHA's Women's Empowerment and Prison Education Program (WEPEP) (PBHA)",
#  'Pediatric Pals',
#  'Peer Health Exchange (PHE) (PBHA)',
#  'Pets as Therapy (PBHA)',
#  'Philippine Forum',
#  'Phillips Brooks House Association (PBHA)',
#  'Photography Club',
#  'Piano Society',
#  'Polish Society',
#  'Political Review (HPR)',
#  'Pop Culture Club',
#  'Pops Orchestra',
#  'Pre-Medical Society',
#  'Pre-Veterinary Society',
#  'Presencia Latina',
#  'Program for International Education (HPIE)',
#  'Progressive Jewish Alliance (PJA)',
#  'Project for Asian and International Relations (HPAIR)',
#  'Project for Justice',
#  'Quad Sound Studios (QSS)',
#  'Quantitative Trading Club',
#  'Queer Students and Allies (QSA)',
#  'Radcliffe Choral Society (RCS)',
#  'Radcliffe Pitches',
#  'Radcliffe Union of Students (RUS)',
#  'Raftaar',
#  'RAZA',
#  'Recent Immigrant Term-Time Enrichment (RITE) (PBHA)',
#  'Recreational Experience and Arts Creativity with Harvard (REACH)',
#  'Red Cross',
#  'Refugee Youth Summer Enrichment (RYSE) (PBHA)',
#  'Republican Club',
#  'Reserve Officer Training Corps Association (HROTCA)',
#  'Response',
#  'Review of Environment and Society',
#  'Right to Life',
#  'River Charles Ensemble',
#  'Robotics Club',
#  'Romanian Association',
#  'Room 13',
#  'Rootstrikers',
#  'Roxbury Youth Initiative (RYI) (PBHA)',
#  'Roxbury Youth Initiative Term (RYIT) (PBHA)',
#  'Rural Health Association',
#  'Russian Speakers Association',
#  'Satire V',
#  'Scholars at Risk',
#  'School of Rock',
#  'Science Club for Girls',
#  'Science Fiction Association (HRSFA)',
#  'Science Review',
#  'Scientista',
#  'Senior Class Committee',
#  'Seventh-day Adventist Fellowship (HCSDAF)',
#  'Sexual Health and Relationship Counselors (SHARC)',
#  'Sexual Health Education & Advocacy throughout Harvard College (SHEATH)',
#  'SHADE',
#  'Sikh Student Association',
#  'Simplicissimus',
#  'Singaporean, Indonesia, and Malaysia Association (SIAMA)',
#  'Slav Squad',
#  'Small Claims Advisory Service (SCAS) (PBHA)',
#  'Smart Woman Securities (SWS)',
#  'Social Enterprise Association (HCSEA)',
#  'Social Innovation Collaborative',
#  'Society for Mind, Brain, and Behavior (HSMBB)',
#  'Society for the Cinematic Arts',
#  'Society of Arab Students',
#  'Society of Black Scientists and Engineers (HSBSE)',
#  'Society of Physics Students (SPS)',
#  'SoulFood Christian Fellowship',
#  'South Asian Association (SAA)',
#  "South Asian Men's Collective (SAMC)",
#  "South Asian Women's Collective",
#  'South Boston Afterschool Program (SAS) (PBHA)',
#  'South Boston Big Sibling Program (PBHA)',
#  'South Boston Outreach Summer (SBOS) (PBHA)',
#  'South Slavic Society',
#  'Speak Out Loud (SOL)',
#  'Special Olympics',
#  'Sports Analysis Collective',
#  'Springboard Design',
#  'Stand-Up Comic Society (HCSUCS)',
#  'Stem Cell Society',
#  'Story-Time Players',
#  'STRIVE',
#  'Strong Women, Strong Girls (SWSG) (PBHA)',
#  'Student Astronomers at Harvard-Radcliffe (STAHR)',
#  'Student for Myanmar',
#  'Student Labor Action Movement (SLAM) (PBHA)',
#  'Student Mental Health Liaisons (SMHL)',
#  'Student Theater Advancing Growth & Empowerment (S.T.A.G.E.)',
#  'Students for Israel',
#  'Students for the Exploration and Development of Space (SEDS)',
#  'Suffolk Prison Education (PBHA)',
#  'Summer Science (PBHA)',
#  'Swiss Club',
#  'Taiwan Leadership Conference',
#  'Taiwanese Cultural Society (TCS)',
#  'TAMID',
#  'TAPS',
#  'Task Force on Asian and Pacific American Studies',
#  'Team HBV',
#  'TEDx Harvard College',
#  'Tempus',
#  'Texas Club',
#  'Thai Society',
#  'The Advocate',
#  'The Harvard Callbacks',
#  'The Harvard Krokodiloes, Inc.',
#  'The Harvard Undergraduate Research Journal (THURJ)',
#  'The Ichthus',
#  'The Independent',
#  'The Review of Philosophy',
#  'The Salient',
#  'Three Letter Acronym: Harold Team (TLA)',
#  'THUD (The Harvard Undergraduate Drummers)',
#  'Tuesday Magazine',
#  'Turkish Student Association',
#  'Under Construction',
#  'Undergraduate Alumni Connection (HUAC)',
#  'Undergraduate Council (UC)',
#  'Undergraduate Fellowship (HUF)',
#  'Undergraduate Legal Committee (PBHA)',
#  'Undergraduate Research Association (HCURA)',
#  'United World Club',
#  'University Choir',
#  'US-India Initiative',
#  'Vegetarian Society (Vegitas)',
#  'Ventures (Harvard College)',
#  'Veritas Financial Group (VFG)',
#  'Veritones',
#  'Veritutor Writing Helpline',
#  'Video Game Development Club',
#  'Vietnamese Association',
#  'VISION',
#  'WHRB (Harvard Radio Broadcasting)',
#  'Wind Ensemble',
#  'Wine Society',
#  'Wireless Club',
#  'Wisconsin Club (H-COW)',
#  'Women in Business (HUWIB)',
#  'Women in Computer Science',
#  'Women In Science at Harvard-Radcliffe (WISHR)',
#  "Women's Leadership Project (WLP)",
#  'Woodbridge International Society',
#  'World Model United Nations (WorldMUN)',
#  "Writers' Workshop",
#  'Writing and Public Service Initiative',
#  'Y2Y- (Young Adults Uniting to End Homelessness (PBHA)',
#  'Yearbook',
#  'Youth Recreation Program- HOOPs (PBHA)',
#  'YouthGlobe']

# %%
toy
# Out:
# ['', 'abc', ' def ']

# %%
[t for t in toy if t != '']
# Out:
# ['abc', ' def ']

# %%
[].extend([1,2,3]).extend([4,5,6])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-fea182a3d888> in <module>()
# ----> 1 [].extend([1,2,3]).extend([4,5,6])
#
# AttributeError: 'NoneType' object has no attribute 'extend'

# %%
[].extend
# Out:
# <function extend>

# %%
st = ["a","b","c PBHA"]

# %%
[s for s in st if s.find("PBHA") < 0]
# Out:
# ['a', 'b']

# %%
a = [3,2,1]

# %%
a.sort()

# %%
a
# Out:
# [1, 2, 3]
